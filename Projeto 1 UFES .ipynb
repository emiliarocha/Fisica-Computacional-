# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = np.linspace(-50,50,200)
y = x+np.cos(x)

# %%
plt.plot(x,y,"r")
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico de x+cos(x)')
plt.grid()
